# %%
import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import f1_score
from sklearn.metrics import det_curve
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.ensemble import RandomForestClassifier
from collections import Counter
import matplotlib.pyplot as plt
import  pandas as pd
import numpy as np

# %%
datos = pd.read_csv('train (1).csv')
datos
# Out:
#        Id               Tipo  FechaConstruccion  FechaReforma  Plantas  \
# 0       1  Chalet individual               2003          2003        2
# 1       2  Chalet individual               1976          1976        1
# 2       3  Chalet individual               2001          2002        2
# 3       4  Chalet individual               1915          1970        2
# 4       5  Chalet individual               2000          2000        2
# ..    ...                ...                ...           ...      ...
# 995   996  Chalet individual               1946          1950        1
# 996   997  Chalet individual               1961          1961        1
# 997   998  Chalet individual               1970          1970        1
# 998   999  Chalet individual               1922          1950        1
# 999  1000  Chalet individual               2006          2006        1
#
#         Plan  PAU               CatParcela  PerimParcela  Superficie  ...  \
# 0    Antiguo    0  Residencial unifamiliar         79.25      785.03  ...
# 1    Antiguo    0  Residencial unifamiliar         97.54      891.87  ...
# 2    Antiguo    0  Residencial unifamiliar         82.91     1045.16  ...
# 3      Nuevo    0  Residencial unifamiliar         73.15      887.22  ...
# 4    Antiguo    0  Residencial unifamiliar        102.41     1324.80  ...
# ..       ...  ...                      ...           ...         ...  ...
# 995      NaN    0  Residencial unifamiliar         62.18      437.76  ...
# 996  Antiguo    0  Residencial unifamiliar           NaN      990.25  ...
# 997  Antiguo    0  Residencial unifamiliar           NaN     1088.54  ...
# 998    Nuevo    0       Residencial tipo 2         73.15      909.15  ...
# 999  Antiguo    0  Residencial unifamiliar         78.03      628.21  ...
#
#      AguaCorriente  FosaSeptica        Situacion     CP  ProxCarretera  \
# 0                1            0         Interior  60061              0
# 1                1            0  Frontal 2 lados  50018              0
# 2                1            0         Interior  60061              0
# 3                1            0          Esquina  62451              0
# 4                1            0  Frontal 2 lados  60706              0
# ..             ...          ...              ...    ...            ...
# 995              1            0         Interior  62801              0
# 996              1            0         Interior  50014              0
# 997              1            0         Interior  50012              0
# 998              1            0         Interior  60406              0
# 999              1            0         Interior  60061              0
#
#      ProxCallePrincipal  ProxViasTren Estado RatingEstrellas  Precio
# 0                     0             0      5             3.5  375497
# 1                     1             0      8             3.0  339946
# 2                     0             0      5             3.5  402511
# 3                     0             0      5             3.5  272706
# 4                     0             0      5             4.0  450236
# ..                  ...           ...    ...             ...     ...
# 995                   1             0      7             2.0  236865
# 996                   0             0      6             2.5  265888
# 997                   0             0      6             3.0  320360
# 998                   0             0      4             1.5  177259
# 999                   0             0      5             3.5  343005
#
# [1000 rows x 31 columns]

# %% [markdown]
# voy a hacer un peque;o analisis inicial de los datos

# %%
datos.isna().sum()
# Out:
# Id                      0
# Tipo                    0
# FechaConstruccion       0
# FechaReforma            0
# Plantas                 0
# Plan                  233
# PAU                     0
# CatParcela              0
# PerimParcela          173
# Superficie              0
# Aseos                   0
# Habitaciones            0
# Garaje                  0
# Piscina                 0
# Vallada                 0
# CallePavimentada        0
# Callejon                0
# Formato                 0
# TipoDesnivel            0
# Desnivel                0
# GasNatural              0
# AguaCorriente           0
# FosaSeptica             0
# Situacion               0
# CP                      0
# ProxCarretera           0
# ProxCallePrincipal      0
# ProxViasTren            0
# Estado                  0
# RatingEstrellas         0
# Precio                  0
# dtype: int64

# %% [markdown]
# vemos que nos faltan datos de plan y de perimetro de la parcela, vamos a ver que tipos de plan tenemos

# %%
datos['Plan'].unique()
# Out:
# array(['Antiguo', 'Nuevo', nan], dtype=object)

# %% [markdown]
# vemos que puede ser solo antiguo o nuevo

# %% [markdown]
# El perimetro de parcela puede venir dado por el area o superficie, vamos a intentar encontrar un multiplo medio para imputar los valores

# %%
datos['multiplo_medio'] = datos['Superficie'] / datos['PerimParcela']
multiplo_medio = datos['multiplo_medio'].mean()
multiplo_medio
# Out:
# 11.041549379174883

# %%
valores_faltantes = datos['PerimParcela'].isna()
datos.loc[valores_faltantes, 'PerimParcela'] = datos.loc[valores_faltantes, 'Superficie'] / multiplo_medio

# %%
datos.drop(['multiplo_medio'], axis=1, inplace= True)

# %%
datos.isna().sum()
# Out:
# Id                      0
# Tipo                    0
# FechaConstruccion       0
# FechaReforma            0
# Plantas                 0
# Plan                  233
# PAU                     0
# CatParcela              0
# PerimParcela            0
# Superficie              0
# Aseos                   0
# Habitaciones            0
# Garaje                  0
# Piscina                 0
# Vallada                 0
# CallePavimentada        0
# Callejon                0
# Formato                 0
# TipoDesnivel            0
# Desnivel                0
# GasNatural              0
# AguaCorriente           0
# FosaSeptica             0
# Situacion               0
# CP                      0
# ProxCarretera           0
# ProxCallePrincipal      0
# ProxViasTren            0
# Estado                  0
# RatingEstrellas         0
# Precio                  0
# dtype: int64

# %% [markdown]
# el siguiente paso es intentar sacar algun parametro del que depende el plan urbanistico

# %%
datos['CP'].unique()
# Out:
# array([60061, 50018, 62451, 60706, 62040, 50011, 50012, 61704, 62801,
#        50010, 60645, 50014, 50015, 60406, 60936, 61528, 50017, 60118,
#        62447, 60646, 61705, 61615, 61874], dtype=int64)

# %%
datos[datos['Plan'] == 'Nuevo']
# Out:
#       Id               Tipo  FechaConstruccion  FechaReforma  Plantas   Plan  \
# 3      4  Chalet individual               1915          1970        2  Nuevo
# 29    30  Chalet individual               1927          1950        1  Nuevo
# 30    31  Chalet individual               1920          1950        2  Nuevo
# 63    64  Chalet individual               1921          1950        2  Nuevo
# 68    69  Chalet individual               1945          1950        1  Nuevo
# ..   ...                ...                ...           ...      ...    ...
# 939  940  Chalet individual               1940          1950        2  Nuevo
# 974  975  Chalet individual               1910          1993        2  Nuevo
# 976  977  Chalet individual               1923          1958        1  Nuevo
# 991  992  Chalet individual               1882          1986        2  Nuevo
# 998  999  Chalet individual               1922          1950        1  Nuevo
#
#      PAU               CatParcela  PerimParcela  Superficie  ...  \
# 3      0  Residencial unifamiliar     73.150000      887.22  ...
# 29     0       Residencial tipo 2     73.150000      587.52  ...
# 30     0                Terciario     60.960000      789.68  ...
# 63     0       Residencial tipo 2     60.960000      956.90  ...
# 68     0       Residencial tipo 2     57.300000      428.10  ...
# ..   ...                      ...           ...         ...  ...
# 939    0  Residencial unifamiliar    202.691662     2238.03  ...
# 974    0  Residencial unifamiliar     73.150000     1060.40  ...
# 976    0  Residencial unifamiliar     62.180000      548.13  ...
# 991    0       Residencial tipo 2    147.520000     1641.69  ...
# 998    0       Residencial tipo 2     73.150000      909.15  ...
#
#      AguaCorriente  FosaSeptica  Situacion     CP  ProxCarretera  \
# 3                1            0    Esquina  62451              0
# 29               1            0   Interior  62801              0
# 30               1            0   Interior  60406              0
# 63               1            0   Interior  61704              0
# 68               1            0    Esquina  61704              1
# ..             ...          ...        ...    ...            ...
# 939              1            0   Interior  62447              0
# 974              1            0    Esquina  62801              0
# 976              1            0   Interior  62801              0
# 991              1            0    Esquina  61704              1
# 998              1            0   Interior  60406              0
#
#      ProxCallePrincipal  ProxViasTren Estado RatingEstrellas  Precio
# 3                     0             0      5             3.5  272706
# 29                    1             1      6             2.0  123365
# 30                    1             0      4             2.0   72038
# 63                    1             0      6             3.5  233110
# 68                    0             0      6             2.0  133206
# ..                  ...           ...    ...             ...     ...
# 939                   0             0      7             3.5  406944
# 974                   1             0      8             3.5  290056
# 976                   0             0      7             2.0  166545
# 991                   0             0      9             4.0  290922
# 998                   0             0      4             1.5  177259
#
# [84 rows x 31 columns]

# %%
datos[datos['CP'] == 62801]
# Out:
#       Id               Tipo  FechaConstruccion  FechaReforma  Plantas  \
# 9     10     Chalet adosado               1939          1950        3
# 15    16  Chalet individual               1929          2001        1
# 29    30  Chalet individual               1927          1950        1
# 51    52  Chalet individual               1934          1950        1
# 77    78  Chalet individual               1948          2001        1
# 146  147  Chalet individual               1931          1993        1
# 149  150  Chalet individual               1936          1950        1
# 184  185  Chalet individual               1908          1991        1
# 250  251  Chalet individual               1940          1966        1
# 275  276  Chalet individual               1925          2007        1
# 289  290  Chalet individual               1915          2003        2
# 328  329  Chalet individual               1916          1994        2
# 345  346  Chalet individual               1939          1950        1
# 361  362  Chalet individual               1940          1982        1
# 393  394  Chalet individual               1941          1950        1
# 437  438  Chalet individual               1926          2004        1
# 442  443  Chalet individual               1930          1992        1
# 459  460  Chalet individual               1950          1950        1
# 497  498  Chalet individual               1925          1950        1
# 522  523  Chalet individual               1947          1950        1
# 531  532  Chalet individual               1920          1999        2
# 533  534  Chalet individual               1946          1950        1
# 546  547  Chalet individual               1923          1950        1
# 555  556  Chalet individual               1922          1950        1
# 584  585  Chalet individual               1935          1995        1
# 586  587  Chalet individual               1918          2000        1
# 589  590  Chalet individual               1930          1960        1
# 636  637  Chalet individual               1936          1950        1
# 694  695  Chalet individual               1936          1950        1
# 696  697  Chalet individual               1921          1950        1
# 710  711  Chalet individual               1935          2003        1
# 713  714     Chalet adosado               1970          1970        3
# 761  762  Chalet individual               1924          1950        1
# 807  808  Chalet individual               1923          2004        2
# 826  827  Chalet individual               1924          1950        1
# 912  913  Chalet individual               1925          1950        1
# 935  936  Chalet individual               1926          1953        1
# 960  961  Chalet individual               1958          2008        1
# 974  975  Chalet individual               1910          1993        2
# 976  977  Chalet individual               1923          1958        1
# 995  996  Chalet individual               1946          1950        1
#
#         Plan  PAU               CatParcela  PerimParcela  Superficie  ...  \
# 9        NaN    0  Residencial unifamiliar     60.960000      689.34  ...
# 15       NaN    0       Residencial tipo 2     62.180000      568.57  ...
# 29     Nuevo    0       Residencial tipo 2     73.150000      587.52  ...
# 51       NaN    0       Residencial tipo 2     63.400000      579.71  ...
# 77       NaN    0       Residencial tipo 2     60.960000      802.22  ...
# 146    Nuevo    0       Residencial tipo 2     62.180000      568.57  ...
# 149      NaN    0       Residencial tipo 2     52.502595      579.71  ...
# 184      NaN    0  Residencial unifamiliar    112.170000      691.01  ...
# 250    Nuevo    0  Residencial unifamiliar     67.060000      497.03  ...
# 275      NaN    0  Residencial unifamiliar     67.060000      674.85  ...
# 289    Nuevo    0  Residencial unifamiliar     73.150000      811.04  ...
# 328      NaN    0  Residencial unifamiliar    100.024912     1104.43  ...
# 345      NaN    0  Residencial unifamiliar     79.250000      597.83  ...
# 361      NaN    0  Residencial unifamiliar     76.937572      849.51  ...
# 393    Nuevo    0  Residencial unifamiliar     62.650628      691.76  ...
# 437      NaN    0       Residencial tipo 2     60.960000      557.42  ...
# 442      NaN    0       Residencial tipo 2     63.400000      579.71  ...
# 459      NaN    0  Residencial unifamiliar     59.023419      651.71  ...
# 497      NaN    0  Residencial unifamiliar     73.150000      847.28  ...
# 522      NaN    0       Residencial tipo 2     60.960000      464.52  ...
# 531    Nuevo    0       Residencial tipo 2     73.150000      571.82  ...
# 533  Antiguo    0  Residencial unifamiliar     60.960000      464.52  ...
# 546      NaN    0  Residencial unifamiliar     85.340000      811.69  ...
# 555      NaN    0       Residencial tipo 2     70.710000      592.72  ...
# 584      NaN    0       Residencial tipo 2     62.180000      568.57  ...
# 586    Nuevo    0  Residencial unifamiliar     67.060000      953.84  ...
# 589      NaN    0       Residencial tipo 2     60.960000      845.42  ...
# 636    Nuevo    0       Residencial tipo 2     62.180000      568.57  ...
# 694      NaN    0       Residencial tipo 2     62.180000      568.57  ...
# 696    Nuevo    0       Residencial tipo 2     60.960000      557.42  ...
# 710    Nuevo    0  Residencial unifamiliar     68.280000      383.69  ...
# 713      NaN    0  Residencial unifamiliar     73.150000      917.23  ...
# 761    Nuevo    0       Residencial tipo 2     73.150000      642.05  ...
# 807    Nuevo    0  Residencial unifamiliar    175.560000     1986.64  ...
# 826      NaN    0       Residencial tipo 2     60.960000      569.50  ...
# 912    Nuevo    0       Residencial tipo 2     62.180000      568.57  ...
# 935    Nuevo    0  Residencial unifamiliar     63.400000      541.16  ...
# 960  Antiguo    0  Residencial unifamiliar     60.960000      669.55  ...
# 974    Nuevo    0  Residencial unifamiliar     73.150000     1060.40  ...
# 976    Nuevo    0  Residencial unifamiliar     62.180000      548.13  ...
# 995      NaN    0  Residencial unifamiliar     62.180000      437.76  ...
#
#      AguaCorriente  FosaSeptica        Situacion     CP  ProxCarretera  \
# 9                1            0          Esquina  62801              1
# 15               1            0          Esquina  62801              0
# 29               1            0         Interior  62801              0
# 51               1            0         Interior  62801              0
# 77               1            0         Interior  62801              0
# 146              1            0          Esquina  62801              0
# 149              1            0         Interior  62801              0
# 184              1            0         Interior  62801              0
# 250              1            0         Interior  62801              0
# 275              1            0         Interior  62801              0
# 289              1            0         Interior  62801              0
# 328              1            0         Interior  62801              0
# 345              1            0         Interior  62801              0
# 361              1            0         Interior  62801              0
# 393              1            0          Esquina  62801              0
# 437              1            0         Interior  62801              0
# 442              1            0         Interior  62801              0
# 459              1            0          Esquina  62801              0
# 497              1            0         Interior  62801              0
# 522              1            0          Esquina  62801              0
# 531              1            0  Frontal 3 lados  62801              0
# 533              1            0         Interior  62801              0
# 546              1            0         Interior  62801              0
# 555              1            0         Interior  62801              0
# 584              1            0         Interior  62801              0
# 586              1            0         Interior  62801              0
# 589              1            0         Interior  62801              0
# 636              1            0         Interior  62801              0
# 694              1            0          Esquina  62801              0
# 696              1            0         Interior  62801              0
# 710              1            0         Interior  62801              0
# 713              1            0         Interior  62801              0
# 761              1            0  Frontal 2 lados  62801              0
# 807              1            0         Interior  62801              0
# 826              1            0         Interior  62801              0
# 912              1            0         Interior  62801              0
# 935              1            0         Interior  62801              0
# 960              1            0         Interior  62801              0
# 974              1            0          Esquina  62801              0
# 976              1            0         Interior  62801              0
# 995              1            0         Interior  62801              0
#
#      ProxCallePrincipal  ProxViasTren Estado RatingEstrellas  Precio
# 9                     0             0      6             2.5  212511
# 15                    0             0      8             3.5  247234
# 29                    1             1      6             2.0  123365
# 51                    0             0      6             3.0  223035
# 77                    0             0      5             2.5  228720
# 146                   0             0      7             2.5  181826
# 149                   0             0      4             2.5  224009
# 184                   1             0      8             2.5  247383
# 250                   0             0      2             1.5  127378
# 275                   0             0      7             3.5  354994
# 289                   0             0      7             3.0  287643
# 328                   0             0      6             3.0  371445
# 345                   0             0      5             3.0  273096
# 361                   0             0      5             2.5  261137
# 393                   1             0      5             2.0  194790
# 437                   0             0      7             3.0  206069
# 442                   0             0      7             2.5  293374
# 459                   0             0      4             2.5  190484
# 497                   0             0      6             3.5  331374
# 522                   1             0      7             3.0  309716
# 531                   1             1      8             3.0  230521
# 533                   0             0      3             0.5   73608
# 546                   0             0      7             3.0  393326
# 555                   0             0      6             2.5  220113
# 584                   0             0      7             2.0  230313
# 586                   0             0      7             3.0  234123
# 589                   1             0      6             2.5  143175
# 636                   0             0      3             1.0  103901
# 694                   0             0      6             2.5  245032
# 696                   0             0      7             2.5  173363
# 710                   0             0      6             1.5   93649
# 713                   0             0      5             2.0  251279
# 761                   1             0      5             2.5  173168
# 807                   0             0      6             2.5  387030
# 826                   0             0      6             2.5  197203
# 912                   0             0      7             2.5  171415
# 935                   0             0      5             2.0  155637
# 960                   0             0      7             2.5  193981
# 974                   1             0      8             3.5  290056
# 976                   0             0      7             2.0  166545
# 995                   1             0      7             2.0  236865
#
# [41 rows x 31 columns]

# %% [markdown]
# parece que se ve una pequena caracteristica y es que todos los del plan nuevo parece que tienen una fecha anterior a al menos 1946, ya que el chalet 534 que nos aparece en esa cabecera es de 1946, vamos a probar con eso

# %%
condicion = (datos['FechaConstruccion'] < 1946) & (datos['Plan'] == 'Nuevo')
resultado = datos[condicion]
resultado
# Out:
#       Id               Tipo  FechaConstruccion  FechaReforma  Plantas   Plan  \
# 3      4  Chalet individual               1915          1970        2  Nuevo
# 29    30  Chalet individual               1927          1950        1  Nuevo
# 30    31  Chalet individual               1920          1950        2  Nuevo
# 63    64  Chalet individual               1921          1950        2  Nuevo
# 68    69  Chalet individual               1945          1950        1  Nuevo
# ..   ...                ...                ...           ...      ...    ...
# 939  940  Chalet individual               1940          1950        2  Nuevo
# 974  975  Chalet individual               1910          1993        2  Nuevo
# 976  977  Chalet individual               1923          1958        1  Nuevo
# 991  992  Chalet individual               1882          1986        2  Nuevo
# 998  999  Chalet individual               1922          1950        1  Nuevo
#
#      PAU               CatParcela  PerimParcela  Superficie  ...  \
# 3      0  Residencial unifamiliar     73.150000      887.22  ...
# 29     0       Residencial tipo 2     73.150000      587.52  ...
# 30     0                Terciario     60.960000      789.68  ...
# 63     0       Residencial tipo 2     60.960000      956.90  ...
# 68     0       Residencial tipo 2     57.300000      428.10  ...
# ..   ...                      ...           ...         ...  ...
# 939    0  Residencial unifamiliar    202.691662     2238.03  ...
# 974    0  Residencial unifamiliar     73.150000     1060.40  ...
# 976    0  Residencial unifamiliar     62.180000      548.13  ...
# 991    0       Residencial tipo 2    147.520000     1641.69  ...
# 998    0       Residencial tipo 2     73.150000      909.15  ...
#
#      AguaCorriente  FosaSeptica  Situacion     CP  ProxCarretera  \
# 3                1            0    Esquina  62451              0
# 29               1            0   Interior  62801              0
# 30               1            0   Interior  60406              0
# 63               1            0   Interior  61704              0
# 68               1            0    Esquina  61704              1
# ..             ...          ...        ...    ...            ...
# 939              1            0   Interior  62447              0
# 974              1            0    Esquina  62801              0
# 976              1            0   Interior  62801              0
# 991              1            0    Esquina  61704              1
# 998              1            0   Interior  60406              0
#
#      ProxCallePrincipal  ProxViasTren Estado RatingEstrellas  Precio
# 3                     0             0      5             3.5  272706
# 29                    1             1      6             2.0  123365
# 30                    1             0      4             2.0   72038
# 63                    1             0      6             3.5  233110
# 68                    0             0      6             2.0  133206
# ..                  ...           ...    ...             ...     ...
# 939                   0             0      7             3.5  406944
# 974                   1             0      8             3.5  290056
# 976                   0             0      7             2.0  166545
# 991                   0             0      9             4.0  290922
# 998                   0             0      4             1.5  177259
#
# [83 rows x 31 columns]

# %%
condicion = (datos['FechaConstruccion'] >= 1946) & (datos['Plan'] == 'Antiguo')
resultado = datos[condicion]
resultado
# Out:
#        Id               Tipo  FechaConstruccion  FechaReforma  Plantas  \
# 0       1  Chalet individual               2003          2003        2
# 1       2  Chalet individual               1976          1976        1
# 2       3  Chalet individual               2001          2002        2
# 4       5  Chalet individual               2000          2000        2
# 6       7  Chalet individual               2004          2005        1
# ..    ...                ...                ...           ...      ...
# 993   994  Chalet individual               2005          2006        2
# 994   995  Chalet individual               2006          2007        1
# 996   997  Chalet individual               1961          1961        1
# 997   998  Chalet individual               1970          1970        1
# 999  1000  Chalet individual               2006          2006        1
#
#         Plan  PAU               CatParcela  PerimParcela  Superficie  ...  \
# 0    Antiguo    0  Residencial unifamiliar     79.250000      785.03  ...
# 1    Antiguo    0  Residencial unifamiliar     97.540000      891.87  ...
# 2    Antiguo    0  Residencial unifamiliar     82.910000     1045.16  ...
# 4    Antiguo    0  Residencial unifamiliar    102.410000     1324.80  ...
# 6    Antiguo    0  Residencial unifamiliar     91.440000      936.83  ...
# ..       ...  ...                      ...           ...         ...  ...
# 993  Antiguo    0  Residencial unifamiliar     82.910000      821.82  ...
# 994  Antiguo    0  Residencial unifamiliar    117.040000     1157.20  ...
# 996  Antiguo    0  Residencial unifamiliar     89.683972      990.25  ...
# 997  Antiguo    0  Residencial unifamiliar     98.585802     1088.54  ...
# 999  Antiguo    0  Residencial unifamiliar     78.030000      628.21  ...
#
#      AguaCorriente  FosaSeptica        Situacion     CP  ProxCarretera  \
# 0                1            0         Interior  60061              0
# 1                1            0  Frontal 2 lados  50018              0
# 2                1            0         Interior  60061              0
# 4                1            0  Frontal 2 lados  60706              0
# 6                1            0         Interior  50011              0
# ..             ...          ...              ...    ...            ...
# 993              1            0         Interior  60061              0
# 994              1            0  Frontal 2 lados  60645              0
# 996              1            0         Interior  50014              0
# 997              1            0         Interior  50012              0
# 999              1            0         Interior  60061              0
#
#      ProxCallePrincipal  ProxViasTren Estado RatingEstrellas  Precio
# 0                     0             0      5             3.5  375497
# 1                     1             0      8             3.0  339946
# 2                     0             0      5             3.5  402511
# 4                     0             0      5             4.0  450236
# 6                     0             0      5             4.0  575005
# ..                  ...           ...    ...             ...     ...
# 993                   0             0      5             3.0  338740
# 994                   0             0      5             5.0  584441
# 996                   0             0      6             2.5  265888
# 997                   0             0      6             3.0  320360
# 999                   0             0      5             3.5  343005
#
# [683 rows x 31 columns]

# %%
condicion = (datos['Plan'] == 'Antiguo')
resultado = datos[condicion]
resultado
# Out:
#        Id               Tipo  FechaConstruccion  FechaReforma  Plantas  \
# 0       1  Chalet individual               2003          2003        2
# 1       2  Chalet individual               1976          1976        1
# 2       3  Chalet individual               2001          2002        2
# 4       5  Chalet individual               2000          2000        2
# 6       7  Chalet individual               2004          2005        1
# ..    ...                ...                ...           ...      ...
# 993   994  Chalet individual               2005          2006        2
# 994   995  Chalet individual               2006          2007        1
# 996   997  Chalet individual               1961          1961        1
# 997   998  Chalet individual               1970          1970        1
# 999  1000  Chalet individual               2006          2006        1
#
#         Plan  PAU               CatParcela  PerimParcela  Superficie  ...  \
# 0    Antiguo    0  Residencial unifamiliar     79.250000      785.03  ...
# 1    Antiguo    0  Residencial unifamiliar     97.540000      891.87  ...
# 2    Antiguo    0  Residencial unifamiliar     82.910000     1045.16  ...
# 4    Antiguo    0  Residencial unifamiliar    102.410000     1324.80  ...
# 6    Antiguo    0  Residencial unifamiliar     91.440000      936.83  ...
# ..       ...  ...                      ...           ...         ...  ...
# 993  Antiguo    0  Residencial unifamiliar     82.910000      821.82  ...
# 994  Antiguo    0  Residencial unifamiliar    117.040000     1157.20  ...
# 996  Antiguo    0  Residencial unifamiliar     89.683972      990.25  ...
# 997  Antiguo    0  Residencial unifamiliar     98.585802     1088.54  ...
# 999  Antiguo    0  Residencial unifamiliar     78.030000      628.21  ...
#
#      AguaCorriente  FosaSeptica        Situacion     CP  ProxCarretera  \
# 0                1            0         Interior  60061              0
# 1                1            0  Frontal 2 lados  50018              0
# 2                1            0         Interior  60061              0
# 4                1            0  Frontal 2 lados  60706              0
# 6                1            0         Interior  50011              0
# ..             ...          ...              ...    ...            ...
# 993              1            0         Interior  60061              0
# 994              1            0  Frontal 2 lados  60645              0
# 996              1            0         Interior  50014              0
# 997              1            0         Interior  50012              0
# 999              1            0         Interior  60061              0
#
#      ProxCallePrincipal  ProxViasTren Estado RatingEstrellas  Precio
# 0                     0             0      5             3.5  375497
# 1                     1             0      8             3.0  339946
# 2                     0             0      5             3.5  402511
# 4                     0             0      5             4.0  450236
# 6                     0             0      5             4.0  575005
# ..                  ...           ...    ...             ...     ...
# 993                   0             0      5             3.0  338740
# 994                   0             0      5             5.0  584441
# 996                   0             0      6             2.5  265888
# 997                   0             0      6             3.0  320360
# 999                   0             0      5             3.5  343005
#
# [683 rows x 31 columns]

# %% [markdown]
# hemos comprobado que si la fecha de construccion es menor que 1946 el Plan es Nuevo

# %%
def llenar_plan(row):
    if pd.isna(row['Plan']):
        if row['FechaConstruccion'] < 1946:
            return 'Nuevo'
        else:
            return 'Antiguo'
    else:
        return row['Plan']

# Aplica la función a cada fila del DataFrame
datos['Plan'] = datos.apply(llenar_plan, axis=1)

# %%
datos.isna().sum()
# Out:
# Id                    0
# Tipo                  0
# FechaConstruccion     0
# FechaReforma          0
# Plantas               0
# Plan                  0
# PAU                   0
# CatParcela            0
# PerimParcela          0
# Superficie            0
# Aseos                 0
# Habitaciones          0
# Garaje                0
# Piscina               0
# Vallada               0
# CallePavimentada      0
# Callejon              0
# Formato               0
# TipoDesnivel          0
# Desnivel              0
# GasNatural            0
# AguaCorriente         0
# FosaSeptica           0
# Situacion             0
# CP                    0
# ProxCarretera         0
# ProxCallePrincipal    0
# ProxViasTren          0
# Estado                0
# RatingEstrellas       0
# Precio                0
# dtype: int64

# %% [markdown]
# ya tenemos todos los valorews completos ahora vamos a hacer x e y y unos dummies de los valores no int, Tipo, Plan, CatParcela...

# %%
y = datos['Precio']
x = datos.drop(['Precio'], axis=1)

# %%
datos.dtypes
# Out:
# Id                      int64
# Tipo                   object
# FechaConstruccion       int64
# FechaReforma            int64
# Plantas                 int64
# Plan                   object
# PAU                     int64
# CatParcela             object
# PerimParcela          float64
# Superficie            float64
# Aseos                   int64
# Habitaciones            int64
# Garaje                  int64
# Piscina                 int64
# Vallada                 int64
# CallePavimentada        int64
# Callejon                int64
# Formato                object
# TipoDesnivel           object
# Desnivel               object
# GasNatural              int64
# AguaCorriente           int64
# FosaSeptica             int64
# Situacion              object
# CP                      int64
# ProxCarretera           int64
# ProxCallePrincipal      int64
# ProxViasTren            int64
# Estado                  int64
# RatingEstrellas       float64
# Precio                  int64
# dtype: object

# %%
columnas_no_numericas = x.select_dtypes(exclude=[int, float]).columns

df = pd.get_dummies(x, columns=columnas_no_numericas)
df.head()
# Out:
#    Id  FechaConstruccion  FechaReforma  Plantas  PAU  PerimParcela  \
# 0   1               2003          2003        2    0         79.25
# 1   2               1976          1976        1    0         97.54
# 2   3               2001          2002        2    0         82.91
# 3   4               1915          1970        2    0         73.15
# 4   5               2000          2000        2    0        102.41
#
#    Superficie  Aseos  Habitaciones  Garaje  ...  TipoDesnivel_Llana  \
# 0      785.03      4             8       1  ...                True
# 1      891.87      3             6       1  ...                True
# 2     1045.16      4             6       1  ...                True
# 3      887.22      2             7       1  ...                True
# 4     1324.80      4             9       1  ...                True
#
#    TipoDesnivel_Muy irregular  Desnivel_Elevado  Desnivel_Ligero  \
# 0                       False             False             True
# 1                       False             False             True
# 2                       False             False             True
# 3                       False             False             True
# 4                       False             False             True
#
#    Desnivel_Moderado  Situacion_Esquina  Situacion_Frontal 2 lados  \
# 0              False              False                      False
# 1              False              False                       True
# 2              False              False                      False
# 3              False               True                      False
# 4              False              False                       True
#
#    Situacion_Frontal 3 lados  Situacion_Interior  Situacion_Trasero
# 0                      False                True              False
# 1                      False               False              False
# 2                      False                True              False
# 3                      False               False              False
# 4                      False               False              False
#
# [5 rows x 51 columns]

# %%
df = df.astype(int)

# %% [markdown]
# ahora ya tenemos nuestro df completo, vamos a hacer un zscaler que es mas robusto ante los outliers

# %%
from sklearn.preprocessing import StandardScaler


scaler = StandardScaler()

# Ajustar el scaler a tus datos (calcula la media y la desviación estándar)
scaler.fit(df)

# Realizar la transformación Z-Score en tus datos
x_scaled = scaler.transform(df)

# El resultado estará en forma de un ndarray de Numpy. Puedes convertirlo de nuevo a un DataFrame si es necesario.
x_scaled = pd.DataFrame(x_scaled, columns=df.columns)
x_scaled
# Out:
#            Id  FechaConstruccion  FechaReforma   Plantas       PAU  \
# 0   -1.730320           1.045813      0.868588  1.028881 -0.346151
# 1   -1.726856           0.145601     -0.454806 -0.824959 -0.346151
# 2   -1.723391           0.979130      0.819573  1.028881 -0.346151
# 3   -1.719927          -1.888211     -0.748894  1.028881 -0.346151
# 4   -1.716463           0.945789      0.721544  1.028881 -0.346151
# ..        ...                ...           ...       ...       ...
# 995  1.716463          -0.854635     -1.729186 -0.824959 -0.346151
# 996  1.719927          -0.354517     -1.190025 -0.824959 -0.346151
# 997  1.723391          -0.054446     -0.748894 -0.824959 -0.346151
# 998  1.726856          -1.654823     -1.729186 -0.824959 -0.346151
# 999  1.730320           1.145836      1.015631 -0.824959 -0.346151
#
#      PerimParcela  Superficie     Aseos  Habitaciones    Garaje  ...  \
# 0       -0.146824   -0.196041  1.693652      0.935889  0.243561  ...
# 1        0.103302   -0.096016  0.607978     -0.307817  0.243561  ...
# 2       -0.105136    0.049304  1.693652     -0.307817  0.243561  ...
# 3       -0.230199   -0.099790 -0.477697      0.314036  0.243561  ...
# 4        0.172782    0.312578  1.693652      1.557742  0.243561  ...
# ..            ...         ...       ...           ...       ...  ...
# 995     -0.383054   -0.524426  0.607978     -0.929670  0.243561  ...
# 996     -0.007865   -0.002596 -0.477697     -0.307817  0.243561  ...
# 997      0.117198    0.089880 -0.477697     -0.307817  0.243561  ...
# 998     -0.230199   -0.079030 -1.563371     -0.307817  0.243561  ...
# 999     -0.160720   -0.344192  0.607978     -0.307817  0.243561  ...
#
#      TipoDesnivel_Llana  TipoDesnivel_Muy irregular  Desnivel_Elevado  \
# 0              0.335182                   -0.163383         -0.105463
# 1              0.335182                   -0.163383         -0.105463
# 2              0.335182                   -0.163383         -0.105463
# 3              0.335182                   -0.163383         -0.105463
# 4              0.335182                   -0.163383         -0.105463
# ..                  ...                         ...               ...
# 995            0.335182                   -0.163383         -0.105463
# 996            0.335182                   -0.163383         -0.105463
# 997            0.335182                   -0.163383         -0.105463
# 998            0.335182                   -0.163383         -0.105463
# 999            0.335182                   -0.163383         -0.105463
#
#      Desnivel_Ligero  Desnivel_Moderado  Situacion_Esquina  \
# 0           0.241249          -0.214535          -0.478018
# 1           0.241249          -0.214535          -0.478018
# 2           0.241249          -0.214535          -0.478018
# 3           0.241249          -0.214535           2.091971
# 4           0.241249          -0.214535          -0.478018
# ..               ...                ...                ...
# 995        -4.145096           4.661252          -0.478018
# 996         0.241249          -0.214535          -0.478018
# 997         0.241249          -0.214535          -0.478018
# 998         0.241249          -0.214535          -0.478018
# 999         0.241249          -0.214535          -0.478018
#
#      Situacion_Frontal 2 lados  Situacion_Frontal 3 lados  Situacion_Interior  \
# 0                    -0.178862                  -0.044766            0.629800
# 1                     5.590891                  -0.044766           -1.587806
# 2                    -0.178862                  -0.044766            0.629800
# 3                    -0.178862                  -0.044766           -1.587806
# 4                     5.590891                  -0.044766           -1.587806
# ..                         ...                        ...                 ...
# 995                  -0.178862                  -0.044766            0.629800
# 996                  -0.178862                  -0.044766            0.629800
# 997                  -0.178862                  -0.044766            0.629800
# 998                  -0.178862                  -0.044766            0.629800
# 999                  -0.178862                  -0.044766            0.629800
#
#      Situacion_Trasero
# 0            -0.263664
# 1            -0.263664
# 2            -0.263664
# 3            -0.263664
# 4            -0.263664
# ..                 ...
# 995          -0.263664
# 996          -0.263664
# 997          -0.263664
# 998          -0.263664
# 999          -0.263664
#
# [1000 rows x 51 columns]

# %%
X = x_scaled  # Tus características escaladas

# %% [markdown]
# vale ahora vamos a probar algunos modelos y una cross validation de 10 folds

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, SGDRegressor, TheilSenRegressor, RANSACRegressor, HuberRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_percentage_error,mean_absolute_error
from sklearn.model_selection import KFold, train_test_split

def regresion_con_validacion_cruzada_y_test(X, y):
  
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle= False)
    
    # Inicializa los modelos
    modelos = {
        "Ridge": Ridge(alpha=1.0),
        "Lasso": Lasso(alpha=1.0),
        "Random Forest": RandomForestRegressor(n_estimators=100, random_state=42),
        "Elastic Net": ElasticNet(random_state=42),
        "SGDRegressor": SGDRegressor(max_iter=1000, tol=1e-3),
        "TheilSen": TheilSenRegressor(random_state=0),
        "RANSAC": RANSACRegressor(random_state=0),
        "HURBER": HuberRegressor(),
        "SVR": SVR(epsilon=0.2)
    }
    
 
    resultados = {}
    for nombre, modelo in modelos.items():
        mse_scores = []
        r2_scores = []
        mae_scores = []
        mape_scores = []
        
        kf = KFold(n_splits=10, shuffle=True, random_state=42)
        for train_index, val_index in kf.split(X_train):
            
            train_index = train_index.astype('int64')
            X_train_fold = X_train.iloc[train_index]
            X_val_fold = X_train.iloc[val_index]
            y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[val_index]
            
            modelo.fit(X_train_fold, y_train_fold)
            y_pred = modelo.predict(X_val_fold)
            
            mse_fold = mean_squared_error(y_val_fold, y_pred)
            r2_fold = r2_score(y_val_fold, y_pred)
            mae_fold = mean_absolute_error(y_val_fold, y_pred)
            mape_fold = (mean_absolute_percentage_error(y_val_fold, y_pred)*100)
            
            mse_scores.append(mse_fold)
            r2_scores.append(r2_fold)
            mae_scores.append(mae_fold)
            mape_scores.append(mape_fold)
        

        mse_promedio = np.mean(mse_scores)
        r2_promedio = np.mean(r2_scores)
        mae_promedio = np.mean(mae_scores)
        mape_promedio = np.mean(mape_scores)
        
        # Evalúa el modelo en el conjunto de prueba
        modelo.fit(X_train, y_train)
        y_pred_test = modelo.predict(X_test)
        mse_test = mean_squared_error(y_test, y_pred_test)
        r2_test = r2_score(y_test, y_pred_test)
        mae_test =  mean_absolute_error(y_test, y_pred_test)
        mape_test =  (mean_absolute_percentage_error(y_test, y_pred_test)*100)
        
        resultados[nombre] = {
            'MSE Promedio': mse_promedio,
            'R² Promedio': r2_promedio,
            'MAE Promedio': mae_promedio,
            'MAPE Promedio': mape_promedio,
            'MSE en Test': mse_test,
            'R² en Test': r2_test,
            'MAE en Test': mae_test,
            'MAPE en Test': mape_test
            
        }
    
    return resultados


resultados = regresion_con_validacion_cruzada_y_test(X, y)


for modelo, metricas in resultados.items():
    print(f"Modelo: {modelo}")
    print(f"MSE Promedio en Validación Cruzada: {metricas['MSE Promedio']}")
    print(f"R² Promedio en Validación Cruzada: {metricas['R² Promedio']}")
    print(f"MAE Promedio en Validación Cruzada: {metricas['MAE Promedio']}")
    print(f"MAPE Promedio en Validación Cruzada: {metricas['MAPE Promedio']}")    
    print(f"MSE en Test: {metricas['MSE en Test']}")
    print(f"R² en Test: {metricas['R² en Test']}")
    print(f"MAE en Test: {metricas['MAE en Test']}")
    print(f"MAPE en Test: {metricas['MAPE en Test']}")
    print()
# Out:
# c:\Users\Horiz\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.203e+11, tolerance: 1.654e+09
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Horiz\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.307e+11, tolerance: 1.629e+09
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Horiz\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.062e+11, tolerance: 1.482e+09
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Horiz\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.938e+10, tolerance: 1.687e+09
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Horiz\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.015e+11, tolerance: 1.705e+09
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Horiz\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.171e+11, tolerance: 1.626e+09
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Horiz\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.128e+11, tolerance: 1.681e+09
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Horiz\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.282e+11, tolerance: 1.684e+09
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Horiz\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.277e+11, tolerance: 1.691e+09
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Horiz\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.434e+11, tolerance: 1.592e+09
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Horiz\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.342e+11, tolerance: 1.826e+09
#   model = cd_fast.enet_coordinate_descent(
# Modelo: Ridge
# MSE Promedio en Validación Cruzada: 6578192782.485262
# R² Promedio en Validación Cruzada: 0.7077804663591726
# MAE Promedio en Validación Cruzada: 58223.128154322985
# MAPE Promedio en Validación Cruzada: 19.031095794037565
# MSE en Test: 4559789266.7300625
# R² en Test: 0.7255921006886241
# MAE en Test: 49242.662350020815
# MAPE en Test: 16.086776526704636
#
# Modelo: Lasso
# MSE Promedio en Validación Cruzada: 6593170093.252617
# R² Promedio en Validación Cruzada: 0.7071978190632537
# MAE Promedio en Validación Cruzada: 58260.348682596545
# MAPE Promedio en Validación Cruzada: 19.049996903982596
# MSE en Test: 4562701003.643607
# R² en Test: 0.7254168725008604
# MAE en Test: 49281.57780843411
# MAPE en Test: 16.104201519045688
#
# Modelo: Random Forest
# MSE Promedio en Validación Cruzada: 5647900881.7888365
# R² Promedio en Validación Cruzada: 0.7477476566238004
# MAE Promedio en Validación Cruzada: 48496.81787500001
# MAPE Promedio en Validación Cruzada: 15.117160486071654
# MSE en Test: 3959662863.1030617
# R² en Test: 0.761707678867234
# MAE en Test: 41217.2723
# MAPE en Test: 13.65838351341566
#
# Modelo: Elastic Net
# MSE Promedio en Validación Cruzada: 6891524607.40085
# R² Promedio en Validación Cruzada: 0.699700366790659
# MAE Promedio en Validación Cruzada: 56658.27144580366
# MAPE Promedio en Validación Cruzada: 17.32915630030438
# MSE en Test: 4775453128.340579
# R² en Test: 0.712613459843592
# MAE en Test: 45776.05323683484
# MAPE en Test: 14.593599967160161
#
# Modelo: SGDRegressor
# MSE Promedio en Validación Cruzada: 6582658508.101641
# R² Promedio en Validación Cruzada: 0.703081107931005
# MAE Promedio en Validación Cruzada: 58628.412470470284
# MAPE Promedio en Validación Cruzada: 19.202500684196572
# MSE en Test: 5897262202.27185
# R² en Test: 0.6451030435943177
# MAE en Test: 51289.98520753823
# MAPE en Test: 16.908174663633424
#
# Modelo: TheilSen
# MSE Promedio en Validación Cruzada: 14638807182.92509
# R² Promedio en Validación Cruzada: 0.29906659851805434
# MAE Promedio en Validación Cruzada: 79912.47194515078
# MAPE Promedio en Validación Cruzada: 28.505244798766523
# MSE en Test: 11996365114.972109
# R² en Test: 0.27805932291856317
# MAE en Test: 74240.9192369774
# MAPE en Test: 28.303888576987312
#
# Modelo: RANSAC
# MSE Promedio en Validación Cruzada: 1.090314714099298e+34
# R² Promedio en Validación Cruzada: -6.66866841049794e+23
# MAE Promedio en Validación Cruzada: 5623872659399278.0
# MAPE Promedio en Validación Cruzada: 1776989016284.1016
# MSE en Test: 3.329184441195536e+30
# R² en Test: -2.0035015995020237e+20
# MAE en Test: 129019076954721.4
# MAPE en Test: 54185563128.91239
#
# Modelo: HURBER
# MSE Promedio en Validación Cruzada: 6829730260.32254
# R² Promedio en Validación Cruzada: 0.7039549976383892
# MAE Promedio en Validación Cruzada: 55371.877599327374
# MAPE Promedio en Validación Cruzada: 16.84601680296167
# MSE en Test: 4587400155.716962
# R² en Test: 0.7239304787140524
# MAE en Test: 45570.251352982035
# MAPE en Test: 14.63804033810925
#
# Modelo: SVR
# MSE Promedio en Validación Cruzada: 24086344189.926586
# R² Promedio en Validación Cruzada: -0.06988180977660596
# MAE Promedio en Validación Cruzada: 108660.09681457565
# MAPE Promedio en Validación Cruzada: 34.13918163826519
# MSE en Test: 16946182478.62187
# R² en Test: -0.019820448553453218
# MAE en Test: 86623.29299212903
# MAPE en Test: 29.868140920682173
